# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import os
num=0
files = glob.glob('./combine/*')
print(files[num])

name = 'merge'
array = np.load(files[num])
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'gray')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

##입꼬리
name = 'tail'
array = np.load(files[num])[95:115, 127:147]
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

##위에
name = 'up'
array = np.load(files[num])[66:86,86:106]
fig,ax = plt.subplots()
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()
# Out:
# ./combine\around_0.npy

# %%
num=1
files = glob.glob('./combine/*')
print(files[num])

name = 'merge'
array = np.load(files[num])
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'gray')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()


##위에
name = 'up'
array = np.load(files[num])[60:80, 85:105]
fig,ax = plt.subplots()
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

##입꼬리
name = 'tail'
array = np.load(files[num])[85:105, 122:142]
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()
# Out:
# ./combine\b_0.npy

# %%
num=2
files = glob.glob('./combine/*')
print(files[num])

name = 'merge'
array = np.load(files[num])
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'gray')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()


##위에
name = 'up'
array = np.load(files[num])[55:75, 79:99]
fig,ax = plt.subplots()
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

##입꼬리
name = 'tail'
array = np.load(files[num])[81:101, 122:142]
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()
# Out:
# ./combine\fracture_0.npy

# %%
num=3
files = glob.glob('./combine/*')
print(files[num])

name = 'merge'
array = np.load(files[num])
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'gray')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()


##위에
name = 'up'
array = np.load(files[num])[55:75, 78:98]
fig,ax = plt.subplots()
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

##입꼬리
name = 'tail'
array = np.load(files[num])[81:101, 125:145]
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

# %%
num=4
files = glob.glob('./combine/*')
print(files[num])

name = 'merge'
array = np.load(files[num])
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'gray')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()


##위에
name = 'up'
array = np.load(files[num])[60:80, 85:105]
fig,ax = plt.subplots()
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

##입꼬리
name = 'tail'
array = np.load(files[num])[85:105, 125:145]
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()
# Out:
# ./combine\mechanics_0.npy

# %%
num=5
files = glob.glob('./combine/*')
print(files[num])

name = 'merge'
array = np.load(files[num])
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'gray')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()


##위에
name = 'up'
array = np.load(files[num])[58:78, 93:113]
fig,ax = plt.subplots()
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

##입꼬리
name = 'tail'
array = np.load(files[num])[83:103, 134:154]
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()
# Out:
# ./combine\science_0.npy

# %%
num=6
files = glob.glob('./combine/*')
print(files[num])

name = 'merge'
array = np.load(files[num])
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'gray')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()


##위에
name = 'up'
array = np.load(files[num])[65:85,87:107]
fig,ax = plt.subplots()
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

##입꼬리
name = 'tail'
array = np.load(files[num])[88:108, 133:153]
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()
# Out:
# ./combine\smile_0.npy

# %%
num=7
files = glob.glob('./combine/*')
print(files[num])

name = 'merge'
array = np.load(files[num])
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'gray')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()


##위에
name = 'up'
array = np.load(files[num])[58:78, 76:96]
fig,ax = plt.subplots()
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

##입꼬리
name = 'tail'
array = np.load(files[num])[82:102,115:135]
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()
# Out:
# ./combine\strain_0.npy

# %%
num=8
files = glob.glob('./combine/*')
print(files[num])

name = 'merge'
array = np.load(files[num])
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'gray')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()


##위에
name = 'up'
array = np.load(files[num])[67:87, 85:105]
fig,ax = plt.subplots()
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

##입꼬리
name = 'tail'
array = np.load(files[num])[92:112,127:147]
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()
# Out:
# ./combine\stress_0.npy

# %%
num=9
files = glob.glob('./combine/*')
print(files[num])

name = 'merge'
array = np.load(files[num])
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'gray')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()


##위에
name = 'up'
array = np.load(files[num])[85:105, 80:100]
fig,ax = plt.subplots()
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()

##입꼬리
name = 'tail'
array = np.load(files[num])[110:130,116:136]
a = array[:,:,0] + array[:,:,1] + array[:,:,2] + array[:,:,3] + array[:,:,4]  \
    + array[:,:,5] + array[:,:,6]  + array[:,:,7] + array[:,:,8] + array[:,:,9]
fig,ax = plt.subplots()
ax.imshow(a, cmap= 'Blues')
plt.axis('off')
plt.savefig('./{}_{}.png'.format(os.path.basename(files[num]),name),dpi= 300,bbox_inches='tight',
               transparent=True,
               pad_inches=0)

plt.show()
plt.close()
# Out:
# ./combine\t_0.npy

# %%
name = 'merge'
array = np.load('./science/science_23.npy')
for i in range(10):
    a = array[:,:,i]
    fig,ax = plt.subplots()
    ax.imshow(a, cmap= 'gray')
    plt.axis('off')
    plt.savefig('./science/{}.png'.format(i),dpi= 300,bbox_inches='tight',
                   transparent=True,
                   pad_inches=0)

    plt.show()
    plt.close()
