# %%
import numpy as np

a = np.load('data/science/science_2.npy')
a.shape
# Out:
# (20, 270, 270, 5)

# %%
import matplotlib.pyplot as plt
a[0][:,:,0].shape
plt.imshow(a[0][:,:,0])

# %%
plt.imshow(a[0][:,:,1])

# %%
plt.imshow(a[0][:,:,2])

# %%
plt.imshow(a[0][:,:,3])

# %%
plt.imshow(a[0][:,:,4])

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-b09102c82b1b> in <module>
# ----> 1 plt.imshow(a[0][:,:,5])
#
# IndexError: index 5 is out of bounds for axis 2 with size 5
